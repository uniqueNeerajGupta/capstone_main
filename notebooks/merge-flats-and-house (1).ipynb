# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('/Users/yogeshgupta/neeraj/data/processed/flats_cleaned.csv')
houses = pd.read_csv('/Users/yogeshgupta/neeraj/data/processed/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0                            2 BHK Flat in Sohna          flat
# 1                2 BHK Flat in Sector 95 Gurgaon          flat
# 2        4 Bedroom House for sale in Palam Vihar         house
# 3  5 Bedroom House for sale in Sector 57 Gurgaon         house
# 4                  3 BHK Flat in Sector-33 Sohna          flat
#
#                      society  price  price_per_sqft    area  \
# 0        trisara our homes 3   0.34          5405.0   629.0
# 1  signature global superbia   0.40          6728.0   595.0
# 2                independent   4.99         18889.0  2642.0
# 3                independent   8.00        266666.0   300.0
# 4         godrej nature plus   1.55          9955.0  1557.0
#
#                         areaWithType  bedRoom  bathroom balcony  \
# 0     Carpet area: 629 (58.44 sq.m.)        2         2       1
# 1  Carpet area: 594.52 (55.23 sq.m.)        2         2       3
# ...

# %%
df.to_csv('/Users/yogeshgupta/neeraj/data/processed/gurgaon_properties.csv',index=False)
